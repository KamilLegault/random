# %%
library(arules)
# Out:
# Loading required package: Matrix
#
# Attaching package: ‘arules’
#
# The following objects are masked from ‘package:base’:
#
#     abbreviate, write

# %%
data("AdultUCI")
AdultUCI[["fnlwgt"]] <- NULL
AdultUCI[["education-num"]] <- NULL

## map metric attributes
AdultUCI[[ "age"]] <- ordered(cut(AdultUCI[[ "age"]], c(15,25,45,65,100)),
  labels = c("Young", "Middle-aged", "Senior", "Old"))

AdultUCI[[ "hours-per-week"]] <- ordered(cut(AdultUCI[[ "hours-per-week"]],
  c(0,25,40,60,168)),
  labels = c("Part-time", "Full-time", "Over-time", "Workaholic"))

AdultUCI[[ "capital-gain"]] <- ordered(cut(AdultUCI[[ "capital-gain"]],
  c(-Inf,0,median(AdultUCI[[ "capital-gain"]][AdultUCI[[ "capital-gain"]]>0]),
  Inf)), labels = c("None", "Low", "High"))

AdultUCI[[ "capital-loss"]] <- ordered(cut(AdultUCI[[ "capital-loss"]],
  c(-Inf,0, median(AdultUCI[[ "capital-loss"]][AdultUCI[[ "capital-loss"]]>0]),
  Inf)), labels = c("None", "Low", "High"))

# %%
#AdultUCI[[ "capital-gain"]] <- NULL
#AdultUCI[[ "capital-loss"]] <- NULL

# %%
fsets <- apriori(AdultUCI, parameter = list(supp = 0.2))
fsets.top5 <- sort(fsets)[1:300]
inspect(fsets.top5)
# Out:
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5     0.2      1
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 9768
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[115 item(s), 48842 transaction(s)] done [0.03s].
# sorting and recoding items ... [18 item(s)] done [0.01s].
# creating transaction tree ... done [0.03s].
# checking subsets of size 1 2 3 4 5 6 7 done [0.01s].
# writing ... [1306 rule(s)] done [0.00s].
# creating S4 object  ... done [0.01s].
#       lhs                                    rhs                                   support confidence      lift
# [1]   {}                                  => {capital-loss=None}                 0.9532779  0.9532779 1.0000000
# [2]   {}                                  => {capital-gain=None}                 0.9173867  0.9173867 1.0000000
# [3]   {}                                  => {native-country=United-States}      0.8974243  0.8974243 1.0000000
# [4]   {capital-gain=None}                 => {capital-loss=None}                 0.8706646  0.9490705 0.9955863
# [5]   {capital-loss=None}                 => {capital-gain=None}                 0.8706646  0.9133376 0.9955863
# [6]   {}                                  => {race=White}                        0.8550428  0.8550428 1.0000000
# [7]   {native-country=United-States}      => {capital-loss=None}                 0.8548380  0.9525461 0.9992323
# [8]   {capital-loss=None}                 => {native-country=United-States}      0.8548380  0.8967354 0.9992323
# [9]   {native-country=United-States}      => {capital-gain=None}                 0.8219565  0.9159062 0.9983862
# [10]  {capital-gain=None}                 => {native-country=United-States}      0.8219565  0.8959761 0.9983862
# [11]  {race=White}                        => {capital-loss=None}                 0.8136849  0.9516307 0.9982720
# [12]  {capital-loss=None}                 => {race=White}                        0.8136849  0.8535653 0.9982720
# [13]  {race=White}                        => {native-country=United-States}      0.7881127  0.9217231 1.0270761
# [14]  {native-country=United-States}      => {race=White}                        0.7881127  0.8781940 1.0270761
# [15]  {race=White}                        => {capital-gain=None}                 0.7817862  0.9143240 0.9966616
# [16]  {capital-gain=None}                 => {race=White}                        0.7817862  0.8521883 0.9966616
# [17]  {capital-gain=None,
#        native-country=United-States}      => {capital-loss=None}                 0.7793702  0.9481891 0.9946618
# [18]  {capital-loss=None,
#        native-country=United-States}      => {capital-gain=None}                 0.7793702  0.9117168 0.9938195
# [19]  {capital-gain=None,
#        capital-loss=None}                 => {native-country=United-States}      0.7793702  0.8951440 0.9974590
# [20]  {race=White,
#        native-country=United-States}      => {capital-loss=None}                 0.7490480  0.9504325 0.9970152
# [21]  {race=White,
#        capital-loss=None}                 => {native-country=United-States}      0.7490480  0.9205626 1.0257830
# [22]  {capital-loss=None,
#        native-country=United-States}      => {race=White}                        0.7490480  0.8762454 1.0247972
# [23]  {race=White,
#        capital-gain=None}                 => {capital-loss=None}                 0.7404283  0.9470983 0.9935175
# [24]  {race=White,
#        capital-loss=None}                 => {capital-gain=None}                 0.7404283  0.9099693 0.9919147
# [25]  {capital-gain=None,
#        capital-loss=None}                 => {race=White}                        0.7404283  0.8504174 0.9945905
# [26]  {race=White,
#        native-country=United-States}      => {capital-gain=None}                 0.7194628  0.9128933 0.9951019
# [27]  {race=White,
#        capital-gain=None}                 => {native-country=United-States}      0.7194628  0.9202807 1.0254689
# [28]  {capital-gain=None,
#        native-country=United-States}      => {race=White}                        0.7194628  0.8753051 1.0236975
# [29]  {race=White,
#        capital-gain=None,
#        native-country=United-States}      => {capital-loss=None}                 0.6803980  0.9457029 0.9920537
# [30]  {race=White,
#        capital-loss=None,
#        native-country=United-States}      => {capital-gain=None}                 0.6803980  0.9083504 0.9901500
# [31]  {race=White,
#        capital-gain=None,
#        capital-loss=None}                 => {native-country=United-States}      0.6803980  0.9189249 1.0239581
# [32]  {capital-gain=None,
#        capital-loss=None,
#        native-country=United-States}      => {race=White}                        0.6803980  0.8730100 1.0210133
# [33]  {workclass=Private}                 => {capital-loss=None}                 0.6639982  0.9564974 1.0033773
# [34]  {workclass=Private}                 => {capital-gain=None}                 0.6413742  0.9239073 1.0071078
# [35]  {sex=Male}                          => {capital-loss=None}                 0.6331027  0.9470750 0.9934931
# [36]  {workclass=Private}                 => {native-country=United-States}      0.6171942  0.8890757 0.9906971
# [37]  {workclass=Private,
#        capital-gain=None}                 => {capital-loss=None}                 0.6111748  0.9529145 0.9996188
# [38]  {workclass=Private,
#        capital-loss=None}                 => {capital-gain=None}                 0.6111748  0.9204465 1.0033354
# [39]  {sex=Male}                          => {capital-gain=None}                 0.6050735  0.9051455 0.9866565
# [40]  {sex=Male}                          => {native-country=United-States}      0.5983170  0.8950383 0.9973412
# [41]  {workclass=Private}                 => {race=White}                        0.5942427  0.8560137 1.0011355
# [42]  {workclass=Private,
#        native-country=United-States}      => {capital-loss=None}                 0.5897179  0.9554818 1.0023119
# [43]  {workclass=Private,
#        capital-loss=None}                 => {native-country=United-States}      0.5897179  0.8881317 0.9896452
# [44]  {sex=Male}                          => {race=White}                        0.5883256  0.8800919 1.0292957
# [45]  {sex=Male,
#        capital-gain=None}                 => {capital-loss=None}                 0.5696941  0.9415288 0.9876750
# [46]  {sex=Male,
#        capital-loss=None}                 => {capital-gain=None}                 0.5696941  0.8998448 0.9808784
# [47]  {workclass=Private,
#        native-country=United-States}      => {capital-gain=None}                 0.5689570  0.9218444 1.0048592
# [48]  {workclass=Private,
#        capital-gain=None}                 => {native-country=United-States}      0.5689570  0.8870906 0.9884851
# [49]  {workclass=Private,
#        race=White}                        => {capital-loss=None}                 0.5674829  0.9549683 1.0017732
# [50]  {workclass=Private,
#        capital-loss=None}                 => {race=White}                        0.5674829  0.8546452 0.9995351
# [51]  {sex=Male,
#        native-country=United-States}      => {capital-loss=None}                 0.5661316  0.9462068 0.9925823
# [52]  {sex=Male,
#        capital-loss=None}                 => {native-country=United-States}      0.5661316  0.8942177 0.9964268
# [53]  {hours-per-week=Full-time}          => {capital-loss=None}                 0.5606650  0.9582531 1.0052191
# [54]  {race=White,
#        sex=Male}                          => {capital-loss=None}                 0.5564268  0.9457804 0.9921350
# [55]  {sex=Male,
#        capital-loss=None}                 => {race=White}                        0.5564268  0.8788888 1.0278887
# [56]  {workclass=Private,
#        race=White}                        => {capital-gain=None}                 0.5472339  0.9208931 1.0038221
# [57]  {workclass=Private,
#        capital-gain=None}                 => {race=White}                        0.5472339  0.8532210 0.9978693
# [58]  {hours-per-week=Full-time}          => {capital-gain=None}                 0.5435895  0.9290688 1.0127342
# [59]  {workclass=Private,
#        race=White}                        => {native-country=United-States}      0.5433848  0.9144157 1.0189334
# [60]  {workclass=Private,
#        native-country=United-States}      => {race=White}                        0.5433848  0.8804113 1.0296693
# [61]  {race=White,
#        sex=Male}                          => {native-country=United-States}      0.5415421  0.9204803 1.0256912
# [62]  {sex=Male,
#        native-country=United-States}      => {race=White}                        0.5415421  0.9051090 1.0585540
# [63]  {workclass=Private,
#        capital-gain=None,
#        native-country=United-States}      => {capital-loss=None}                 0.5414807  0.9517075 0.9983526
# [64]  {workclass=Private,
#        capital-loss=None,
#        native-country=United-States}      => {capital-gain=None}                 0.5414807  0.9182030 1.0008898
# [65]  {workclass=Private,
#        capital-gain=None,
#        capital-loss=None}                 => {native-country=United-States}      0.5414807  0.8859670 0.9872330
# [66]  {sex=Male,
#        native-country=United-States}      => {capital-gain=None}                 0.5406003  0.9035349 0.9849008
# [67]  {sex=Male,
#        capital-gain=None}                 => {native-country=United-States}      0.5406003  0.8934457 0.9955666
# [68]  {race=White,
#        sex=Male}                          => {capital-gain=None}                 0.5313050  0.9030799 0.9844048
# [69]  {sex=Male,
#        capital-gain=None}                 => {race=White}                        0.5313050  0.8780834 1.0269468
# [70]  {workclass=Private,
#        race=White,
#        capital-gain=None}                 => {capital-loss=None}                 0.5204742  0.9511000 0.9977153
# [71]  {workclass=Private,
#        race=White,
#        capital-loss=None}                 => {capital-gain=None}                 0.5204742  0.9171628 0.9997559
# [72]  {workclass=Private,
#        capital-gain=None,
#        capital-loss=None}                 => {race=White}                        0.5204742  0.8515963 0.9959692
# [73]  {capital-gain=None,
#        hours-per-week=Full-time}          => {capital-loss=None}                 0.5191638  0.9550659 1.0018756
# [74]  {capital-loss=None,
#        hours-per-week=Full-time}          => {capital-gain=None}                 0.5191638  0.9259787 1.0093657
# [75]  {workclass=Private,
#        race=White,
#        native-country=United-States}      => {capital-loss=None}                 0.5181401  0.9535418 1.0002768
# [76]  {workclass=Private,
#        race=White,
#        capital-loss=None}                 => {native-country=United-States}      0.5181401  0.9130498 1.0174114
# [77]  {workclass=Private,
#        capital-loss=None,
#        native-country=United-States}      => {race=White}                        0.5181401  0.8786238 1.0275787
# [78]  {hours-per-week=Full-time}          => {native-country=United-States}      0.5179559  0.8852574 0.9864423
# [79]  {race=White,
#        sex=Male,
#        native-country=United-States}      => {capital-loss=None}                 0.5113632  0.9442722 0.9905529
# [80]  {race=White,
#        sex=Male,
#        capital-loss=None}                 => {native-country=United-States}      0.5113632  0.9190124 1.0240556
# [81]  {sex=Male,
#        capital-loss=None,
#        native-country=United-States}      => {race=White}                        0.5113632  0.9032585 1.0563898
# [82]  {sex=Male,
#        capital-gain=None,
#        native-country=United-States}      => {capital-loss=None}                 0.5084149  0.9404636 0.9865576
# [83]  {sex=Male,
#        capital-loss=None,
#        native-country=United-States}      => {capital-gain=None}                 0.5084149  0.8980507 0.9789228
# [84]  {sex=Male,
#        capital-gain=None,
#        capital-loss=None}                 => {native-country=United-States}      0.5084149  0.8924349 0.9944402
# [85]  {race=White,
#        sex=Male,
#        capital-gain=None}                 => {capital-loss=None}                 0.4994062  0.9399615 0.9860309
# [86]  {race=White,
#        sex=Male,
#        capital-loss=None}                 => {capital-gain=None}                 0.4994062  0.8975236 0.9783482
# [87]  {sex=Male,
#        capital-gain=None,
#        capital-loss=None}                 => {race=White}                        0.4994062  0.8766217 1.0252373
# [88]  {workclass=Private,
#        race=White,
#        native-country=United-States}      => {capital-gain=None}                 0.4994062  0.9190656 1.0018301
# [89]  {workclass=Private,
#        race=White,
#        capital-gain=None}                 => {native-country=United-States}      0.4994062  0.9126010 1.0169114
# [90]  {workclass=Private,
#        capital-gain=None,
#        native-country=United-States}      => {race=White}                        0.4994062  0.8777574 1.0265654
# [91]  {hours-per-week=Full-time,
#        native-country=United-States}      => {capital-loss=None}                 0.4959052  0.9574275 1.0043529
# [92]  {capital-loss=None,
#        hours-per-week=Full-time}          => {native-country=United-States}      0.4959052  0.8844946 0.9855924
# [93]  {income=small}                      => {capital-loss=None}                 0.4908480  0.9698220 1.0173549
# [94]  {race=White,
#        sex=Male,
#        native-country=United-States}      => {capital-gain=None}                 0.4881045  0.9013233 0.9824900
# [95]  {race=White,
#        sex=Male,
#        capital-gain=None}                 => {native-country=United-States}      0.4881045  0.9186898 1.0236961
# [96]  {sex=Male,
#        capital-gain=None,
#        native-country=United-States}      => {race=White}                        0.4881045  0.9028935 1.0559629
# [97]  {income=small}                      => {capital-gain=None}                 0.4849310  0.9581311 1.0444135
# [98]  {hours-per-week=Full-time}          => {race=White}                        0.4824741  0.8246142 0.9644128
# [99]  {hours-per-week=Full-time,
#        native-country=United-States}      => {capital-gain=None}                 0.4801196  0.9269507 1.0104253
# [100] {capital-gain=None,
#        hours-per-week=Full-time}          => {native-country=United-States}      0.4801196  0.8832392 0.9841935
# [101] {age=Middle-aged}                   => {capital-loss=None}                 0.4800786  0.9504276 0.9970100
# [102] {workclass=Private,
#        race=White,
#        capital-gain=None,
#        native-country=United-States}      => {capital-loss=None}                 0.4741616  0.9494506 0.9959851
# [103] {workclass=Private,
#        race=White,
#        capital-loss=None,
#        native-country=United-States}      => {capital-gain=None}                 0.4741616  0.9151223 0.9975317
# [104] {workclass=Private,
#        race=White,
#        capital-gain=None,
#        capital-loss=None}                 => {native-country=United-States}      0.4741616  0.9110184 1.0151479
# [105] {workclass=Private,
#        capital-gain=None,
#        capital-loss=None,
#        native-country=United-States}      => {race=White}                        0.4741616  0.8756759 1.0241311
# [106] {capital-gain=None,
#        income=small}                      => {capital-loss=None}                 0.4696573  0.9685033 1.0159716
# [107] {capital-loss=None,
#        income=small}                      => {capital-gain=None}                 0.4696573  0.9568282 1.0429934
# [108] {age=Middle-aged}                   => {capital-gain=None}                 0.4632079  0.9170281 0.9996091
# [109] {race=White,
#        hours-per-week=Full-time}          => {capital-loss=None}                 0.4618566  0.9572671 1.0041847
# [110] {capital-loss=None,
#        hours-per-week=Full-time}          => {race=White}                        0.4618566  0.8237657 0.9634204
# [111] {capital-gain=None,
#        hours-per-week=Full-time,
#        native-country=United-States}      => {capital-loss=None}                 0.4580689  0.9540725 1.0008335
# [112] {capital-loss=None,
#        hours-per-week=Full-time,
#        native-country=United-States}      => {capital-gain=None}                 0.4580689  0.9237026 1.0068847
# [113] {capital-gain=None,
#        capital-loss=None,
#        hours-per-week=Full-time}          => {native-country=United-States}      0.4580689  0.8823205 0.9831697
# [114] {race=White,
#        sex=Male,
#        capital-gain=None,
#        native-country=United-States}      => {capital-loss=None}                 0.4579256  0.9381711 0.9841528
# [115] {race=White,
#        sex=Male,
#        capital-loss=None,
#        native-country=United-States}      => {capital-gain=None}                 0.4579256  0.8954997 0.9761420
# [116] {race=White,
#        sex=Male,
#        capital-gain=None,
#        capital-loss=None}                 => {native-country=United-States}      0.4579256  0.9169400 1.0217463
# [117] {sex=Male,
#        capital-gain=None,
#        capital-loss=None,
#        native-country=United-States}      => {race=White}                        0.4579256  0.9006927 1.0533890
# [118] {income=small}                      => {native-country=United-States}      0.4504115  0.8899272 0.9916459
# [119] {age=Middle-aged}                   => {native-country=United-States}      0.4488760  0.8886547 0.9902280
# [120] {race=White,
#        hours-per-week=Full-time}          => {capital-gain=None}                 0.4468081  0.9260768 1.0094727
# [121] {capital-gain=None,
#        hours-per-week=Full-time}          => {race=White}                        0.4468081  0.8219586 0.9613069
# [122] {race=White,
#        hours-per-week=Full-time}          => {native-country=United-States}      0.4394988  0.9109272 1.0150463
# [123] {hours-per-week=Full-time,
#        native-country=United-States}      => {race=White}                        0.4394988  0.8485256 0.9923779
# [124] {age=Middle-aged,
#        capital-gain=None}                 => {capital-loss=None}                 0.4381680  0.9459424 0.9923049
# [125] {age=Middle-aged,
#        capital-loss=None}                 => {capital-gain=None}                 0.4381680  0.9127004 0.9948918
# [126] {native-country=United-States,
#        income=small}                      => {capital-loss=None}                 0.4366119  0.9693622 1.0168727
# [127] {capital-loss=None,
#        income=small}                      => {native-country=United-States}      0.4366119  0.8895053 0.9911758
# [128] {workclass=Private,
#        sex=Male}                          => {capital-loss=None}                 0.4341346  0.9505536 0.9971422
# [129] {native-country=United-States,
#        income=small}                      => {capital-gain=None}                 0.4313501  0.9576799 1.0439217
# [130] {capital-gain=None,
#        income=small}                      => {native-country=United-States}      0.4313501  0.8895081 0.9911790
# [131] {marital-status=Married-civ-spouse} => {capital-loss=None}                 0.4293026  0.9369498 0.9828716
# [132] {age=Middle-aged,
#        native-country=United-States}      => {capital-loss=None}                 0.4262929  0.9496898 0.9962361
# [133] {age=Middle-aged,
#        capital-loss=None}                 => {native-country=United-States}      0.4262929  0.8879649 0.9894593
# [134] {race=White,
#        capital-gain=None,
#        hours-per-week=Full-time}          => {capital-loss=None}                 0.4261906  0.9538560 1.0006064
# [135] {race=White,
#        capital-loss=None,
#        hours-per-week=Full-time}          => {capital-gain=None}                 0.4261906  0.9227768 1.0058756
# [136] {capital-gain=None,
#        capital-loss=None,
#        hours-per-week=Full-time}          => {race=White}                        0.4261906  0.8209173 0.9600891
# [137] {age=Middle-aged}                   => {race=White}                        0.4253511  0.8420818 0.9848417
# [138] {income=small}                      => {race=White}                        0.4237951  0.8373382 0.9792939
# [139] {race=White,
#        hours-per-week=Full-time,
#        native-country=United-States}      => {capital-loss=None}                 0.4200278  0.9556974 1.0025380
# [140] {race=White,
#        capital-loss=None,
#        hours-per-week=Full-time}          => {native-country=United-States}      0.4200278  0.9094335 1.0133818
# [141] {capital-loss=None,
#        hours-per-week=Full-time,
#        native-country=United-States}      => {race=White}                        0.4200278  0.8469923 0.9905847
# [142] {capital-gain=None,
#        native-country=United-States,
#        income=small}                      => {capital-loss=None}                 0.4175505  0.9680084 1.0154524
# [143] {capital-loss=None,
#        native-country=United-States,
#        income=small}                      => {capital-gain=None}                 0.4175505  0.9563423 1.0424637
# [144] {capital-gain=None,
#        capital-loss=None,
#        income=small}                      => {native-country=United-States}      0.4175505  0.8890536 0.9906724
# [145] {workclass=Private,
#        sex=Male}                          => {capital-gain=None}                 0.4160763  0.9110145 0.9930540
# [146] {race=White,
#        income=small}                      => {capital-loss=None}                 0.4106916  0.9690806 1.0165772
# [147] {capital-loss=None,
#        income=small}                      => {race=White}                        0.4106916  0.8366981 0.9785453
# [148] {age=Middle-aged,
#        native-country=United-States}      => {capital-gain=None}                 0.4106711  0.9148878 0.9972761
# [149] {age=Middle-aged,
#        capital-gain=None}                 => {native-country=United-States}      0.4106711  0.8865806 0.9879168
# [150] {marital-status=Married-civ-spouse} => {race=White}                        0.4105892  0.8961080 1.0480270
# [151] {marital-status=Married-civ-spouse} => {native-country=United-States}      0.4095451  0.8938290 0.9959937
# [152] {marital-status=Married-civ-spouse} => {sex=Male}                          0.4074157  0.8891818 1.3301506
# [153] {workclass=Private,
#        hours-per-week=Full-time}          => {capital-loss=None}                 0.4064330  0.9620063 1.0091562
# [154] {race=White,
#        hours-per-week=Full-time,
#        native-country=United-States}      => {capital-gain=None}                 0.4059826  0.9237399 1.0069253
# [155] {race=White,
#        capital-gain=None,
#        hours-per-week=Full-time}          => {native-country=United-States}      0.4059826  0.9086285 1.0124848
# [156] {capital-gain=None,
#        hours-per-week=Full-time,
#        native-country=United-States}      => {race=White}                        0.4059826  0.8455864 0.9889404
# [157] {race=White,
#        income=small}                      => {capital-gain=None}                 0.4054093  0.9566163 1.0427623
# [158] {capital-gain=None,
#        income=small}                      => {race=White}                        0.4054093  0.8360144 0.9777456
# [159] {workclass=Private,
#        sex=Male}                          => {native-country=United-States}      0.4044265  0.8855068 0.9867203
# [160] {relationship=Husband}              => {sex=Male}                          0.4036485  0.9999493 1.4958506
# [161] {relationship=Husband}              => {marital-status=Married-civ-spouse} 0.4034233  0.9993914 2.1811642
# [162] {marital-status=Married-civ-spouse} => {relationship=Husband}              0.4034233  0.8804683 2.1811642
# [163] {age=Middle-aged,
#        race=White}                        => {capital-loss=None}                 0.4034233  0.9484477 0.9949330
# [164] {age=Middle-aged,
#        capital-loss=None}                 => {race=White}                        0.4034233  0.8403275 0.9827900
# [165] {marital-status=Married-civ-spouse,
#        relationship=Husband}              => {sex=Male}                          0.4034028  0.9999492 1.4958506
# [166] {relationship=Husband,
#        sex=Male}                          => {marital-status=Married-civ-spouse} 0.4034028  0.9993913 2.1811641
# [167] {marital-status=Married-civ-spouse,
#        sex=Male}                          => {relationship=Husband}              0.4034028  0.9901503 2.4528768
# [168] {marital-status=Married-civ-spouse} => {capital-gain=None}                 0.4032595  0.8801108 0.9593673
# [169] {workclass=Private,
#        sex=Male}                          => {race=White}                        0.4013349  0.8787376 1.0277119
# [170] {workclass=Private,
#        hours-per-week=Full-time}          => {capital-gain=None}                 0.3952131  0.9354495 1.0196894
# [171] {workclass=Private,
#        sex=Male,
#        capital-gain=None}                 => {capital-loss=None}                 0.3934933  0.9457238 0.9920757
# [172] {workclass=Private,
#        sex=Male,
#        capital-loss=None}                 => {capital-gain=None}                 0.3934933  0.9063856 0.9880082
# [173] {race=White,
#        capital-gain=None,
#        income=small}                      => {capital-loss=None}                 0.3923058  0.9676784 1.0151063
# [174] {race=White,
#        capital-loss=None,
#        income=small}                      => {capital-gain=None}                 0.3923058  0.9552321 1.0412535
# [175] {capital-gain=None,
#        capital-loss=None,
#        income=small}                      => {race=White}                        0.3923058  0.8353023 0.9769129
# [176] {age=Middle-aged,
#        race=White}                        => {native-country=United-States}      0.3902584  0.9174970 1.0223669
# [177] {age=Middle-aged,
#        native-country=United-States}      => {race=White}                        0.3902584  0.8694125 1.0168059
# [178] {age=Middle-aged,
#        race=White}                        => {capital-gain=None}                 0.3884976  0.9133574 0.9956079
# [179] {age=Middle-aged,
#        capital-gain=None}                 => {race=White}                        0.3884976  0.8387111 0.9808996
# [180] {age=Middle-aged,
#        capital-gain=None,
#        native-country=United-States}      => {capital-loss=None}                 0.3880881  0.9450095 0.9913263
# [181] {age=Middle-aged,
#        capital-loss=None,
#        native-country=United-States}      => {capital-gain=None}                 0.3880881  0.9103789 0.9923612
# [182] {age=Middle-aged,
#        capital-gain=None,
#        capital-loss=None}                 => {native-country=United-States}      0.3880881  0.8857063 0.9869426
# [183] {race=White,
#        income=small}                      => {native-country=United-States}      0.3873101  0.9139089 1.0183687
# [184] {native-country=United-States,
#        income=small}                      => {race=White}                        0.3873101  0.8599027 1.0056838
# [185] {race=White,
#        capital-gain=None,
#        hours-per-week=Full-time,
#        native-country=United-States}      => {capital-loss=None}                 0.3865116  0.9520399 0.9987013
# [186] {race=White,
#        capital-loss=None,
#        hours-per-week=Full-time,
#        native-country=United-States}      => {capital-gain=None}                 0.3865116  0.9202047 1.0030718
# [187] {race=White,
#        capital-gain=None,
#        capital-loss=None,
#        hours-per-week=Full-time}          => {native-country=United-States}      0.3865116  0.9068985 1.0105571
# [188] {capital-gain=None,
#        capital-loss=None,
#        hours-per-week=Full-time,
#        native-country=United-States}      => {race=White}                        0.3865116  0.8437849 0.9868336
# [189] {marital-status=Married-civ-spouse,
#        race=White}                        => {capital-loss=None}                 0.3844232  0.9362721 0.9821607
# [190] {marital-status=Married-civ-spouse,
#        capital-loss=None}                 => {race=White}                        0.3844232  0.8954597 1.0472689
# [191] {workclass=Private,
#        sex=Male,
#        native-country=United-States}      => {capital-loss=None}                 0.3838500  0.9491217 0.9956400
# [192] {workclass=Private,
#        sex=Male,
#        capital-loss=None}                 => {native-country=United-States}      0.3838500  0.8841728 0.9852338
# [193] {marital-status=Married-civ-spouse,
#        native-country=United-States}      => {capital-loss=None}                 0.3833176  0.9359596 0.9818329
# [194] {marital-status=Married-civ-spouse,
#        capital-loss=None}                 => {native-country=United-States}      0.3833176  0.8928844 0.9949411
# ...
# [250] {relationship=Husband,
#        native-country=United-States}      => {sex=Male}                          0.3630482  0.9999436 1.4958421
# [251] {marital-status=Married-civ-spouse,
#        relationship=Husband}              => {native-country=United-States}      0.3628230  0.8993605 1.0021575
# [252] {relationship=Husband,
#        native-country=United-States}      => {marital-status=Married-civ-spouse} 0.3628230  0.9993233 2.1810156
# [253] {marital-status=Married-civ-spouse,
#        native-country=United-States}      => {relationship=Husband}              0.3628230  0.8859171 2.1946624
# [254] {marital-status=Married-civ-spouse,
#        relationship=Husband,
#        sex=Male}                          => {native-country=United-States}      0.3628025  0.8993554 1.0021518
# [255] {marital-status=Married-civ-spouse,
#        relationship=Husband,
#        native-country=United-States}      => {sex=Male}                          0.3628025  0.9999436 1.4958421
# [256] {relationship=Husband,
#        sex=Male,
#        native-country=United-States}      => {marital-status=Married-civ-spouse} 0.3628025  0.9993233 2.1810155
# [257] {marital-status=Married-civ-spouse,
#        sex=Male,
#        native-country=United-States}      => {relationship=Husband}              0.3628025  0.9923279 2.4582715
# [258] {marital-status=Married-civ-spouse,
#        race=White}                        => {capital-gain=None}                 0.3606322  0.8783285 0.9574245
# [259] {marital-status=Married-civ-spouse,
#        capital-gain=None}                 => {race=White}                        0.3606322  0.8942933 1.0459047
# [260] {marital-status=Married-civ-spouse,
#        native-country=United-States}      => {capital-gain=None}                 0.3597519  0.8784182 0.9575223
# [261] {marital-status=Married-civ-spouse,
#        capital-gain=None}                 => {native-country=United-States}      0.3597519  0.8921101 0.9940783
# [262] {marital-status=Married-civ-spouse,
#        sex=Male}                          => {capital-gain=None}                 0.3586872  0.8803960 0.9596782
# [263] {marital-status=Married-civ-spouse,
#        capital-gain=None}                 => {sex=Male}                          0.3586872  0.8894699 1.3305817
# [264] {race=White,
#        capital-gain=None,
#        native-country=United-States,
#        income=small}                      => {capital-loss=None}                 0.3581549  0.9666243 1.0140005
# [265] {race=White,
#        capital-loss=None,
#        native-country=United-States,
#        income=small}                      => {capital-gain=None}                 0.3581549  0.9552231 1.0412437
# [266] {race=White,
#        capital-gain=None,
#        capital-loss=None,
#        income=small}                      => {native-country=United-States}      0.3581549  0.9129482 1.0172982
# [267] {capital-gain=None,
#        capital-loss=None,
#        native-country=United-States,
#        income=small}                      => {race=White}                        0.3581549  0.8577523 1.0031688
# [268] {age=Middle-aged,
#        race=White,
#        native-country=United-States}      => {capital-gain=None}                 0.3557799  0.9116521 0.9937490
# [269] {age=Middle-aged,
#        race=White,
#        capital-gain=None}                 => {native-country=United-States}      0.3557799  0.9157839 1.0204581
# [270] {age=Middle-aged,
#        capital-gain=None,
#        native-country=United-States}      => {race=White}                        0.3557799  0.8663376 1.0132097
# [271] {relationship=Husband}              => {capital-gain=None}                 0.3552271  0.8799959 0.9592421
# [272] {relationship=Husband,
#        sex=Male}                          => {capital-gain=None}                 0.3552066  0.8799899 0.9592355
# [273] {relationship=Husband,
#        capital-gain=None}                 => {sex=Male}                          0.3552066  0.9999424 1.4958403
# [274] {sex=Male,
#        hours-per-week=Full-time}          => {capital-loss=None}                 0.3551042  0.9536482 1.0003884
# [275] {marital-status=Married-civ-spouse,
#        relationship=Husband}              => {capital-gain=None}                 0.3550018  0.8799736 0.9592178
# [276] {relationship=Husband,
#        capital-gain=None}                 => {marital-status=Married-civ-spouse} 0.3550018  0.9993660 2.1811088
# [277] {marital-status=Married-civ-spouse,
#        capital-gain=None}                 => {relationship=Husband}              0.3550018  0.8803310 2.1808241
# [278] {marital-status=Married-civ-spouse,
#        relationship=Husband,
#        sex=Male}                          => {capital-gain=None}                 0.3549814  0.8799675 0.9592111
# [279] {marital-status=Married-civ-spouse,
#        relationship=Husband,
#        capital-gain=None}                 => {sex=Male}                          0.3549814  0.9999423 1.4958402
# [280] {relationship=Husband,
#        sex=Male,
#        capital-gain=None}                 => {marital-status=Married-civ-spouse} 0.3549814  0.9993660 2.1811087
# [281] {marital-status=Married-civ-spouse,
#        sex=Male,
#        capital-gain=None}                 => {relationship=Husband}              0.3549814  0.9896684 2.4516830
# [282] {workclass=Private,
#        hours-per-week=Full-time,
#        native-country=United-States}      => {capital-loss=None}                 0.3543057  0.9609618 1.0080605
# [283] {workclass=Private,
#        capital-loss=None,
#        hours-per-week=Full-time}          => {native-country=United-States}      0.3543057  0.8717445 0.9713849
# [284] {marital-status=Married-civ-spouse,
#        race=White,
#        native-country=United-States}      => {capital-loss=None}                 0.3540600  0.9346557 0.9804651
# [285] {marital-status=Married-civ-spouse,
#        race=White,
#        capital-loss=None}                 => {native-country=United-States}      0.3540600  0.9210162 1.0262884
# [286] {marital-status=Married-civ-spouse,
#        capital-loss=None,
#        native-country=United-States}      => {race=White}                        0.3540600  0.9236727 1.0802649
# [287] {workclass=Private,
#        income=small}                      => {capital-loss=None}                 0.3526678  0.9713528 1.0189608
# [288] {workclass=Private,
#        hours-per-week=Full-time}          => {race=White}                        0.3501495  0.8287860 0.9692919
# [289] {workclass=Private,
#        income=small}                      => {capital-gain=None}                 0.3488186  0.9607511 1.0472696
# [290] {age=Middle-aged,
#        workclass=Private}                 => {capital-loss=None}                 0.3481225  0.9520157 0.9986759
# [291] {workclass=Private,
#        sex=Male,
#        capital-gain=None,
#        native-country=United-States}      => {capital-loss=None}                 0.3468531  0.9439987 0.9902660
# [292] {workclass=Private,
#        sex=Male,
#        capital-loss=None,
#        native-country=United-States}      => {capital-gain=None}                 0.3468531  0.9036164 0.9849897
# [293] {workclass=Private,
#        sex=Male,
#        capital-gain=None,
#        capital-loss=None}                 => {native-country=United-States}      0.3468531  0.8814715 0.9822237
# [294] {workclass=Private,
#        race=White,
#        sex=Male,
#        native-country=United-States}      => {capital-loss=None}                 0.3464027  0.9472594 0.9936865
# [295] {workclass=Private,
#        race=White,
#        sex=Male,
#        capital-loss=None}                 => {native-country=United-States}      0.3464027  0.9092815 1.0132124
# [296] {workclass=Private,
#        sex=Male,
#        capital-loss=None,
#        native-country=United-States}      => {race=White}                        0.3464027  0.9024429 1.0554360
# [297] {marital-status=Married-civ-spouse,
#        race=White,
#        sex=Male}                          => {capital-loss=None}                 0.3449081  0.9360449 0.9819224
# [298] {marital-status=Married-civ-spouse,
#        sex=Male,
#        capital-loss=None}                 => {race=White}                        0.3449081  0.9039493 1.0571978
# [299] {marital-status=Married-civ-spouse,
#        race=White,
#        capital-loss=None}                 => {sex=Male}                          0.3449081  0.8972092 1.3421590
# [300] {workclass=Private,
#        race=White,
#        sex=Male,
#        capital-gain=None}                 => {capital-loss=None}                 0.3443348  0.9441419 0.9904162

# %%
## Mine frequent itemsets with Eclat.
fsets <- eclat(AdultUCI, parameter = list(supp = 0.2))

## Display the 5 itemsets with the highest support.
fsets.top5 <- sort(fsets)[1:5]
inspect(fsets.top5)
# Out:
# Eclat
#
# parameter specification:
#  tidLists support minlen maxlen            target   ext
#     FALSE     0.2      1     10 frequent itemsets FALSE
#
# algorithmic control:
#  sparse sort verbose
#       7   -2    TRUE
#
# Absolute minimum support count: 9768
#
# create itemset ...
# set transactions ...[109 item(s), 48842 transaction(s)] done [0.04s].
# sorting and recoding items ... [16 item(s)] done [0.01s].
# creating bit matrix ... [16 row(s), 48842 column(s)] done [0.00s].
# writing  ... [179 set(s)] done [0.00s].
# Creating S4 object  ... done [0.00s].
#     items                                     support
# [1] {native-country=United-States}            0.8974243
# [2] {race=White}                              0.8550428
# [3] {race=White,native-country=United-States} 0.7881127
# [4] {workclass=Private}                       0.6941976
# [5] {sex=Male}                                0.6684820

# %%
## Get the itemsets as a list
as(items(fsets.top5), "list")

## Get the itemsets as a binary matrix
as(items(fsets.top5), "matrix")

## Get the itemsets as a sparse matrix, a ngCMatrix from package Matrix.
## Warning: for efficiency reasons, the ngCMatrix you get is transposed 
as(items(fsets.top5), "ngCMatrix")
# Out:
# [[1]]
# [1] "native-country=United-States"
#
# [[2]]
# [1] "race=White"
#
# [[3]]
# [1] "race=White"                   "native-country=United-States"
#
# [[4]]
# [1] "workclass=Private"
#
# [[5]]
# [1] "sex=Male"
#      age=Young age=Middle-aged age=Senior age=Old workclass=Federal-gov
# [1,] FALSE     FALSE           FALSE      FALSE   FALSE
# [2,] FALSE     FALSE           FALSE      FALSE   FALSE
# [3,] FALSE     FALSE           FALSE      FALSE   FALSE
# [4,] FALSE     FALSE           FALSE      FALSE   FALSE
# [5,] FALSE     FALSE           FALSE      FALSE   FALSE
#      workclass=Local-gov workclass=Never-worked workclass=Private
# [1,] FALSE               FALSE                  FALSE
# [2,] FALSE               FALSE                  FALSE
# [3,] FALSE               FALSE                  FALSE
# [4,] FALSE               FALSE                   TRUE
# [5,] FALSE               FALSE                  FALSE
#      workclass=Self-emp-inc workclass=Self-emp-not-inc ...
# [1,] FALSE                  FALSE                      ...
# [2,] FALSE                  FALSE                      ...
# [3,] FALSE                  FALSE                      ...
# [4,] FALSE                  FALSE                      ...
# [5,] FALSE                  FALSE                      ...
#      native-country=Scotland native-country=South native-country=Taiwan
# [1,] FALSE                   FALSE                FALSE
# [2,] FALSE                   FALSE                FALSE
# [3,] FALSE                   FALSE                FALSE
# [4,] FALSE                   FALSE                FALSE
# [5,] FALSE                   FALSE                FALSE
#      native-country=Thailand native-country=Trinadad&Tobago
# [1,] FALSE                   FALSE
# [2,] FALSE                   FALSE
# [3,] FALSE                   FALSE
# [4,] FALSE                   FALSE
# [5,] FALSE                   FALSE
#      native-country=United-States native-country=Vietnam
# [1,]  TRUE                        FALSE
# [2,] FALSE                        FALSE
# [3,]  TRUE                        FALSE
# [4,] FALSE                        FALSE
# [5,] FALSE                        FALSE
#      native-country=Yugoslavia income=small income=large
# [1,] FALSE                     FALSE        FALSE
# [2,] FALSE                     FALSE        FALSE
# [3,] FALSE                     FALSE        FALSE
# [4,] FALSE                     FALSE        FALSE
# [5,] FALSE                     FALSE        FALSE
# 109 x 5 sparse Matrix of class "ngCMatrix"
#
# age=Young                                 . . . . .
# age=Middle-aged                           . . . . .
# age=Senior                                . . . . .
# age=Old                                   . . . . .
# workclass=Federal-gov                     . . . . .
# workclass=Local-gov                       . . . . .
# workclass=Never-worked                    . . . . .
# workclass=Private                         . . . | .
# workclass=Self-emp-inc                    . . . . .
# workclass=Self-emp-not-inc                . . . . .
# workclass=State-gov                       . . . . .
# workclass=Without-pay                     . . . . .
# education=Preschool                       . . . . .
# education=1st-4th                         . . . . .
# education=5th-6th                         . . . . .
# education=7th-8th                         . . . . .
# education=9th                             . . . . .
# education=10th                            . . . . .
# education=11th                            . . . . .
# education=12th                            . . . . .
# education=HS-grad                         . . . . .
# education=Prof-school                     . . . . .
# education=Assoc-acdm                      . . . . .
# education=Assoc-voc                       . . . . .
# education=Some-college                    . . . . .
# education=Bachelors                       . . . . .
# education=Masters                         . . . . .
# education=Doctorate                       . . . . .
# marital-status=Divorced                   . . . . .
# marital-status=Married-AF-spouse          . . . . .
# marital-status=Married-civ-spouse         . . . . .
# marital-status=Married-spouse-absent      . . . . .
# marital-status=Never-married              . . . . .
# marital-status=Separated                  . . . . .
# marital-status=Widowed                    . . . . .
# occupation=Adm-clerical                   . . . . .
# occupation=Armed-Forces                   . . . . .
# occupation=Craft-repair                   . . . . .
# occupation=Exec-managerial                . . . . .
# occupation=Farming-fishing                . . . . .
# occupation=Handlers-cleaners              . . . . .
# occupation=Machine-op-inspct              . . . . .
# occupation=Other-service                  . . . . .
# occupation=Priv-house-serv                . . . . .
# occupation=Prof-specialty                 . . . . .
# occupation=Protective-serv                . . . . .
# occupation=Sales                          . . . . .
# occupation=Tech-support                   . . . . .
# occupation=Transport-moving               . . . . .
# relationship=Husband                      . . . . .
# relationship=Not-in-family                . . . . .
# relationship=Other-relative               . . . . .
# relationship=Own-child                    . . . . .
# relationship=Unmarried                    . . . . .
# relationship=Wife                         . . . . .
# race=Amer-Indian-Eskimo                   . . . . .
# race=Asian-Pac-Islander                   . . . . .
# race=Black                                . . . . .
# race=Other                                . . . . .
# race=White                                . | | . .
# sex=Female                                . . . . .
# sex=Male                                  . . . . |
# hours-per-week=Part-time                  . . . . .
# hours-per-week=Full-time                  . . . . .
# hours-per-week=Over-time                  . . . . .
# hours-per-week=Workaholic                 . . . . .
# native-country=Cambodia                   . . . . .
# native-country=Canada                     . . . . .
# native-country=China                      . . . . .
# native-country=Columbia                   . . . . .
# native-country=Cuba                       . . . . .
# native-country=Dominican-Republic         . . . . .
# native-country=Ecuador                    . . . . .
# native-country=El-Salvador                . . . . .
# native-country=England                    . . . . .
# native-country=France                     . . . . .
# native-country=Germany                    . . . . .
# native-country=Greece                     . . . . .
# native-country=Guatemala                  . . . . .
# native-country=Haiti                      . . . . .
# native-country=Holand-Netherlands         . . . . .
# native-country=Honduras                   . . . . .
# native-country=Hong                       . . . . .
# native-country=Hungary                    . . . . .
# native-country=India                      . . . . .
# native-country=Iran                       . . . . .
# native-country=Ireland                    . . . . .
# native-country=Italy                      . . . . .
# native-country=Jamaica                    . . . . .
# native-country=Japan                      . . . . .
# native-country=Laos                       . . . . .
# native-country=Mexico                     . . . . .
# native-country=Nicaragua                  . . . . .
# native-country=Outlying-US(Guam-USVI-etc) . . . . .
# native-country=Peru                       . . . . .
# native-country=Philippines                . . . . .
# native-country=Poland                     . . . . .
# native-country=Portugal                   . . . . .
# native-country=Puerto-Rico                . . . . .
# native-country=Scotland                   . . . . .
# native-country=South                      . . . . .
# native-country=Taiwan                     . . . . .
# native-country=Thailand                   . . . . .
# native-country=Trinadad&Tobago            . . . . .
# native-country=United-States              | . | . .
# native-country=Vietnam                    . . . . .
# native-country=Yugoslavia                 . . . . .
# income=small                              . . . . .
# income=large                              . . . . .

# %%
rules <- apriori(AdultUCI,parameter = list(minlen=2, supp=0.30, conf=0.8))

rules.sorted <- sort(rules, by="lift")
inspect(rules.sorted)
# Out:
# Apriori
#
# Parameter specification:
#  confidence minval smax arem  aval originalSupport maxtime support minlen
#         0.8    0.1    1 none FALSE            TRUE       5     0.3      2
#  maxlen target   ext
#      10  rules FALSE
#
# Algorithmic control:
#  filter tree heap memopt load sort verbose
#     0.1 TRUE TRUE  FALSE TRUE    2    TRUE
#
# Absolute minimum support count: 14652
#
# set item appearances ...[0 item(s)] done [0.00s].
# set transactions ...[115 item(s), 48842 transaction(s)] done [0.05s].
# sorting and recoding items ... [14 item(s)] done [0.01s].
# creating transaction tree ... done [0.03s].
# checking subsets of size 1 2 3 4 5 6 done [0.00s].
# writing ... [504 rule(s)] done [0.00s].
# creating S4 object  ... done [0.01s].
#       lhs                                    rhs                                   support confidence      lift
# [1]   {marital-status=Married-civ-spouse,
#        race=White,
#        sex=Male,
#        native-country=United-States}      => {relationship=Husband}              0.3382335  0.9931466 2.4602995
# [2]   {marital-status=Married-civ-spouse,
#        race=White,
#        sex=Male,
#        capital-loss=None,
#        native-country=United-States}      => {relationship=Husband}              0.3159371  0.9927942 2.4594265
# [3]   {marital-status=Married-civ-spouse,
#        sex=Male,
#        native-country=United-States}      => {relationship=Husband}              0.3628025  0.9923279 2.4582715
# [4]   {marital-status=Married-civ-spouse,
#        sex=Male,
#        capital-gain=None,
#        native-country=United-States}      => {relationship=Husband}              0.3187830  0.9920357 2.4575475
# [5]   {marital-status=Married-civ-spouse,
#        sex=Male,
#        capital-loss=None,
#        native-country=United-States}      => {relationship=Husband}              0.3393391  0.9919205 2.4572622
# [6]   {marital-status=Married-civ-spouse,
#        race=White,
#        sex=Male}                          => {relationship=Husband}              0.3654027  0.9916653 2.4566299
# [7]   {marital-status=Married-civ-spouse,
#        race=White,
#        sex=Male,
#        capital-gain=None}                 => {relationship=Husband}              0.3210556  0.9913390 2.4558216
# [8]   {marital-status=Married-civ-spouse,
#        race=White,
#        sex=Male,
#        capital-loss=None}                 => {relationship=Husband}              0.3418984  0.9912739 2.4556604
# [9]   {marital-status=Married-civ-spouse,
#        sex=Male}                          => {relationship=Husband}              0.4034028  0.9901503 2.4528768
# [10]  {marital-status=Married-civ-spouse,
#        sex=Male,
#        capital-loss=None}                 => {relationship=Husband}              0.3776258  0.9896974 2.4517548
# [11]  {marital-status=Married-civ-spouse,
#        sex=Male,
#        capital-gain=None}                 => {relationship=Husband}              0.3549814  0.9896684 2.4516830
# [12]  {marital-status=Married-civ-spouse,
#        sex=Male,
#        capital-gain=None,
#        capital-loss=None}                 => {relationship=Husband}              0.3292044  0.9891117 2.4503040
# [13]  {marital-status=Married-civ-spouse,
#        race=White,
#        native-country=United-States}      => {relationship=Husband}              0.3382540  0.8929305 2.2120365
# [14]  {marital-status=Married-civ-spouse,
#        race=White,
#        capital-loss=None,
#        native-country=United-States}      => {relationship=Husband}              0.3159576  0.8923842 2.2106832
# [15]  {marital-status=Married-civ-spouse,
#        race=White,
#        capital-gain=None}                 => {relationship=Husband}              0.3210761  0.8903145 2.2055560
# [16]  {marital-status=Married-civ-spouse,
#        race=White}                        => {relationship=Husband}              0.3654232  0.8899970 2.2047694
# [17]  {marital-status=Married-civ-spouse,
#        race=White,
#        capital-loss=None}                 => {relationship=Husband}              0.3419188  0.8894333 2.2033730
# [18]  {marital-status=Married-civ-spouse,
#        capital-gain=None,
#        native-country=United-States}      => {relationship=Husband}              0.3188035  0.8861761 2.1953039
# [19]  {marital-status=Married-civ-spouse,
#        native-country=United-States}      => {relationship=Husband}              0.3628230  0.8859171 2.1946624
# [20]  {marital-status=Married-civ-spouse,
#        capital-loss=None,
#        native-country=United-States}      => {relationship=Husband}              0.3393596  0.8853221 2.1931883
# [21]  {relationship=Husband,
#        race=White}                        => {marital-status=Married-civ-spouse} 0.3654232  0.9994400 2.1812704
# [22]  {relationship=Husband,
#        race=White,
#        sex=Male}                          => {marital-status=Married-civ-spouse} 0.3654027  0.9994400 2.1812703
# [23]  {relationship=Husband,
#        race=White,
#        capital-gain=None}                 => {marital-status=Married-civ-spouse} 0.3210761  0.9994264 2.1812407
# [24]  {relationship=Husband,
#        race=White,
#        sex=Male,
#        capital-gain=None}                 => {marital-status=Married-civ-spouse} 0.3210556  0.9994264 2.1812406
# [25]  {relationship=Husband,
#        race=White,
#        capital-loss=None}                 => {marital-status=Married-civ-spouse} 0.3419188  0.9994016 2.1811864
# [26]  {relationship=Husband,
#        race=White,
#        sex=Male,
#        capital-loss=None}                 => {marital-status=Married-civ-spouse} 0.3418984  0.9994015 2.1811863
# [27]  {relationship=Husband,
#        race=White,
#        native-country=United-States}      => {marital-status=Married-civ-spouse} 0.3382540  0.9993951 2.1811723
# [28]  {relationship=Husband,
#        race=White,
#        sex=Male,
#        native-country=United-States}      => {marital-status=Married-civ-spouse} 0.3382335  0.9993950 2.1811722
# [29]  {marital-status=Married-civ-spouse} => {relationship=Husband}              0.4034233  0.8804683 2.1811642
# [30]  {relationship=Husband}              => {marital-status=Married-civ-spouse} 0.4034233  0.9993914 2.1811642
# [31]  {relationship=Husband,
#        sex=Male}                          => {marital-status=Married-civ-spouse} 0.4034028  0.9993913 2.1811641
# [32]  {relationship=Husband,
#        capital-gain=None}                 => {marital-status=Married-civ-spouse} 0.3550018  0.9993660 2.1811088
# [33]  {relationship=Husband,
#        sex=Male,
#        capital-gain=None}                 => {marital-status=Married-civ-spouse} 0.3549814  0.9993660 2.1811087
# [34]  {relationship=Husband,
#        race=White,
#        capital-loss=None,
#        native-country=United-States}      => {marital-status=Married-civ-spouse} 0.3159576  0.9993524 2.1810792
# [35]  {relationship=Husband,
#        race=White,
#        sex=Male,
#        capital-loss=None,
#        native-country=United-States}      => {marital-status=Married-civ-spouse} 0.3159371  0.9993524 2.1810791
# [36]  {relationship=Husband,
#        capital-loss=None}                 => {marital-status=Married-civ-spouse} 0.3776463  0.9993498 2.1810735
# [37]  {relationship=Husband,
#        sex=Male,
#        capital-loss=None}                 => {marital-status=Married-civ-spouse} 0.3776258  0.9993498 2.1810735
# [38]  {relationship=Husband,
#        native-country=United-States}      => {marital-status=Married-civ-spouse} 0.3628230  0.9993233 2.1810156
# [39]  {relationship=Husband,
#        sex=Male,
#        native-country=United-States}      => {marital-status=Married-civ-spouse} 0.3628025  0.9993233 2.1810155
# [40]  {relationship=Husband,
#        capital-gain=None,
#        capital-loss=None}                 => {marital-status=Married-civ-spouse} 0.3292248  0.9993164 2.1810005
# [41]  {relationship=Husband,
#        sex=Male,
#        capital-gain=None,
#        capital-loss=None}                 => {marital-status=Married-civ-spouse} 0.3292044  0.9993163 2.1810004
# [42]  {relationship=Husband,
#        capital-gain=None,
#        native-country=United-States}      => {marital-status=Married-civ-spouse} 0.3188035  0.9992941 2.1809518
# [43]  {relationship=Husband,
#        sex=Male,
#        capital-gain=None,
#        native-country=United-States}      => {marital-status=Married-civ-spouse} 0.3187830  0.9992940 2.1809517
# [44]  {relationship=Husband,
#        capital-loss=None,
#        native-country=United-States}      => {marital-status=Married-civ-spouse} 0.3393596  0.9992765 2.1809136
# [45]  {relationship=Husband,
#        sex=Male,
#        capital-loss=None,
#        native-country=United-States}      => {marital-status=Married-civ-spouse} 0.3393391  0.9992765 2.1809135
# [46]  {marital-status=Married-civ-spouse,
#        capital-gain=None}                 => {relationship=Husband}              0.3550018  0.8803310 2.1808241
# [47]  {marital-status=Married-civ-spouse,
#        capital-loss=None}                 => {relationship=Husband}              0.3776463  0.8796738 2.1791959
# [48]  {marital-status=Married-civ-spouse,
#        capital-gain=None,
#        capital-loss=None}                 => {relationship=Husband}              0.3292248  0.8794094 2.1785409
# [49]  {relationship=Husband}              => {sex=Male}                          0.4036485  0.9999493 1.4958506
# [50]  {marital-status=Married-civ-spouse,
#        relationship=Husband}              => {sex=Male}                          0.4034028  0.9999492 1.4958506
# [51]  {relationship=Husband,
#        capital-loss=None}                 => {sex=Male}                          0.3778715  0.9999458 1.4958454
# [52]  {marital-status=Married-civ-spouse,
#        relationship=Husband,
#        capital-loss=None}                 => {sex=Male}                          0.3776258  0.9999458 1.4958454
# [53]  {relationship=Husband,
#        race=White}                        => {sex=Male}                          0.3656075  0.9999440 1.4958427
# [54]  {marital-status=Married-civ-spouse,
#        relationship=Husband,
#        race=White}                        => {sex=Male}                          0.3654027  0.9999440 1.4958427
# [55]  {relationship=Husband,
#        native-country=United-States}      => {sex=Male}                          0.3630482  0.9999436 1.4958421
# [56]  {marital-status=Married-civ-spouse,
#        relationship=Husband,
#        native-country=United-States}      => {sex=Male}                          0.3628025  0.9999436 1.4958421
# [57]  {relationship=Husband,
#        capital-gain=None}                 => {sex=Male}                          0.3552066  0.9999424 1.4958403
# [58]  {marital-status=Married-civ-spouse,
#        relationship=Husband,
#        capital-gain=None}                 => {sex=Male}                          0.3549814  0.9999423 1.4958402
# [59]  {relationship=Husband,
#        race=White,
#        capital-loss=None}                 => {sex=Male}                          0.3421031  0.9999402 1.4958370
# [60]  {marital-status=Married-civ-spouse,
#        relationship=Husband,
#        race=White,
#        capital-loss=None}                 => {sex=Male}                          0.3418984  0.9999401 1.4958369
# [61]  {relationship=Husband,
#        capital-loss=None,
#        native-country=United-States}      => {sex=Male}                          0.3395848  0.9999397 1.4958363
# [62]  {marital-status=Married-civ-spouse,
#        relationship=Husband,
#        capital-loss=None,
#        native-country=United-States}      => {sex=Male}                          0.3393391  0.9999397 1.4958362
# [63]  {relationship=Husband,
#        race=White,
#        native-country=United-States}      => {sex=Male}                          0.3384382  0.9999395 1.4958360
# [64]  {marital-status=Married-civ-spouse,
#        relationship=Husband,
#        race=White,
#        native-country=United-States}      => {sex=Male}                          0.3382335  0.9999395 1.4958359
# [65]  {relationship=Husband,
#        capital-gain=None,
#        capital-loss=None}                 => {sex=Male}                          0.3294296  0.9999379 1.4958335
# [66]  {marital-status=Married-civ-spouse,
#        relationship=Husband,
#        capital-gain=None,
#        capital-loss=None}                 => {sex=Male}                          0.3292044  0.9999378 1.4958335
# [67]  {relationship=Husband,
#        race=White,
#        capital-gain=None}                 => {sex=Male}                          0.3212399  0.9999363 1.4958312
# [68]  {marital-status=Married-civ-spouse,
#        relationship=Husband,
#        race=White,
#        capital-gain=None}                 => {sex=Male}                          0.3210556  0.9999362 1.4958311
# [69]  {relationship=Husband,
#        capital-gain=None,
#        native-country=United-States}      => {sex=Male}                          0.3190082  0.9999358 1.4958305
# [70]  {marital-status=Married-civ-spouse,
#        relationship=Husband,
#        capital-gain=None,
#        native-country=United-States}      => {sex=Male}                          0.3187830  0.9999358 1.4958304
# [71]  {relationship=Husband,
#        race=White,
#        capital-loss=None,
#        native-country=United-States}      => {sex=Male}                          0.3161418  0.9999352 1.4958296
# [72]  {marital-status=Married-civ-spouse,
#        relationship=Husband,
#        race=White,
#        capital-loss=None,
#        native-country=United-States}      => {sex=Male}                          0.3159371  0.9999352 1.4958296
# [73]  {marital-status=Married-civ-spouse,
#        race=White,
#        native-country=United-States}      => {sex=Male}                          0.3405675  0.8990379 1.3448947
# [74]  {marital-status=Married-civ-spouse,
#        race=White,
#        capital-loss=None,
#        native-country=United-States}      => {sex=Male}                          0.3182302  0.8988030 1.3445432
# [75]  {marital-status=Married-civ-spouse,
#        race=White,
#        capital-gain=None}                 => {sex=Male}                          0.3238606  0.8980357 1.3433953
# [76]  {marital-status=Married-civ-spouse,
#        race=White,
#        capital-gain=None,
#        capital-loss=None}                 => {sex=Male}                          0.3002948  0.8978330 1.3430922
# [77]  {marital-status=Married-civ-spouse,
#        race=White}                        => {sex=Male}                          0.3684739  0.8974269 1.3424847
# [78]  {marital-status=Married-civ-spouse,
#        race=White,
#        capital-loss=None}                 => {sex=Male}                          0.3449081  0.8972092 1.3421590
# [79]  {marital-status=Married-civ-spouse,
#        capital-gain=None,
#        native-country=United-States}      => {sex=Male}                          0.3213423  0.8932332 1.3362112
# [80]  {marital-status=Married-civ-spouse,
#        native-country=United-States}      => {sex=Male}                          0.3656075  0.8927161 1.3354377
# [81]  {marital-status=Married-civ-spouse,
#        capital-loss=None,
#        native-country=United-States}      => {sex=Male}                          0.3421031  0.8924794 1.3350836
# [82]  {marital-status=Married-civ-spouse,
#        capital-gain=None}                 => {sex=Male}                          0.3586872  0.8894699 1.3305817
# [83]  {marital-status=Married-civ-spouse} => {sex=Male}                          0.4074157  0.8891818 1.3301506
# [84]  {marital-status=Married-civ-spouse,
#        capital-gain=None,
#        capital-loss=None}                 => {sex=Male}                          0.3328283  0.8890347 1.3299306
# [85]  {marital-status=Married-civ-spouse,
#        capital-loss=None}                 => {sex=Male}                          0.3815569  0.8887829 1.3295539
# [86]  {marital-status=Married-civ-spouse,
#        relationship=Husband,
#        native-country=United-States}      => {race=White}                        0.3382540  0.9322837 1.0903358
# [87]  {marital-status=Married-civ-spouse,
#        relationship=Husband,
#        sex=Male,
#        native-country=United-States}      => {race=White}                        0.3382335  0.9322799 1.0903313
# [88]  {relationship=Husband,
#        native-country=United-States}      => {race=White}                        0.3384587  0.9322168 1.0902574
# [89]  {relationship=Husband,
#        sex=Male,
#        native-country=United-States}      => {race=White}                        0.3384382  0.9322129 1.0902530
# [90]  {marital-status=Married-civ-spouse,
#        sex=Male,
#        native-country=United-States}      => {race=White}                        0.3405675  0.9315115 1.0894326
# [91]  {marital-status=Married-civ-spouse,
#        relationship=Husband,
#        capital-loss=None,
#        native-country=United-States}      => {race=White}                        0.3159576  0.9310407 1.0888820
# [92]  {marital-status=Married-civ-spouse,
#        relationship=Husband,
#        sex=Male,
#        capital-loss=None,
#        native-country=United-States}      => {race=White}                        0.3159371  0.9310366 1.0888772
# [93]  {relationship=Husband,
#        capital-loss=None,
#        native-country=United-States}      => {race=White}                        0.3161623  0.9309700 1.0887994
# [94]  {relationship=Husband,
#        sex=Male,
#        capital-loss=None,
#        native-country=United-States}      => {race=White}                        0.3161418  0.9309659 1.0887945
# [95]  {marital-status=Married-civ-spouse,
#        sex=Male,
#        capital-loss=None,
#        native-country=United-States}      => {race=White}                        0.3182302  0.9302172 1.0879189
# [96]  {marital-status=Married-civ-spouse,
#        native-country=United-States}      => {race=White}                        0.3788133  0.9249613 1.0817719
# [97]  {marital-status=Married-civ-spouse,
#        capital-loss=None,
#        native-country=United-States}      => {race=White}                        0.3540600  0.9236727 1.0802649
# [98]  {marital-status=Married-civ-spouse,
#        capital-gain=None,
#        native-country=United-States}      => {race=White}                        0.3321936  0.9233965 1.0799419
# [99]  {marital-status=Married-civ-spouse,
#        capital-gain=None,
#        capital-loss=None,
#        native-country=United-States}      => {race=White}                        0.3074403  0.9217925 1.0780659
# [100] {marital-status=Married-civ-spouse,
#        relationship=Husband}              => {race=White}                        0.3654232  0.9058059 1.0593691
# [101] {marital-status=Married-civ-spouse,
#        relationship=Husband,
#        sex=Male}                          => {race=White}                        0.3654027  0.9058011 1.0593635
# [102] {relationship=Husband}              => {race=White}                        0.3656279  0.9057618 1.0593175
# [103] {relationship=Husband,
#        sex=Male}                          => {race=White}                        0.3656075  0.9057570 1.0593119
# [104] {marital-status=Married-civ-spouse,
#        relationship=Husband,
#        capital-loss=None}                 => {race=White}                        0.3419188  0.9053944 1.0588878
# [105] {marital-status=Married-civ-spouse,
#        relationship=Husband,
#        sex=Male,
#        capital-loss=None}                 => {race=White}                        0.3418984  0.9053893 1.0588818
# [106] {relationship=Husband,
#        capital-loss=None}                 => {race=White}                        0.3421236  0.9053476 1.0588330
# [107] {relationship=Husband,
#        sex=Male,
#        capital-loss=None}                 => {race=White}                        0.3421031  0.9053424 1.0588271
# [108] {sex=Male,
#        native-country=United-States}      => {race=White}                        0.5415421  0.9051090 1.0585540
# [109] {marital-status=Married-civ-spouse,
#        relationship=Husband,
#        capital-gain=None}                 => {race=White}                        0.3210761  0.9044351 1.0577659
# [110] {marital-status=Married-civ-spouse,
#        relationship=Husband,
#        sex=Male,
#        capital-gain=None}                 => {race=White}                        0.3210556  0.9044296 1.0577594
# [111] {marital-status=Married-civ-spouse,
#        sex=Male}                          => {race=White}                        0.3684739  0.9044173 1.0577451
# [112] {relationship=Husband,
#        capital-gain=None}                 => {race=White}                        0.3212604  0.9043804 1.0577019
# [113] {relationship=Husband,
#        sex=Male,
#        capital-gain=None}                 => {race=White}                        0.3212399  0.9043749 1.0576955
# [114] {workclass=Private,
#        sex=Male,
#        native-country=United-States}      => {race=White}                        0.3656894  0.9042171 1.0575109
# [115] {marital-status=Married-civ-spouse,
#        sex=Male,
#        capital-loss=None}                 => {race=White}                        0.3449081  0.9039493 1.0571978
# [116] {sex=Male,
#        capital-loss=None,
#        native-country=United-States}      => {race=White}                        0.5113632  0.9032585 1.0563898
# [117] {marital-status=Married-civ-spouse,
#        sex=Male,
#        capital-gain=None}                 => {race=White}                        0.3238606  0.9029054 1.0559769
# [118] {sex=Male,
#        capital-gain=None,
#        native-country=United-States}      => {race=White}                        0.4881045  0.9028935 1.0559629
# [119] {workclass=Private,
#        sex=Male,
#        capital-loss=None,
#        native-country=United-States}      => {race=White}                        0.3464027  0.9024429 1.0554360
# [120] {marital-status=Married-civ-spouse,
#        sex=Male,
#        capital-gain=None,
#        capital-loss=None}                 => {race=White}                        0.3002948  0.9022515 1.0552121
# [121] {workclass=Private,
#        sex=Male,
#        capital-gain=None,
#        native-country=United-States}      => {race=White}                        0.3313951  0.9019280 1.0548338
# [122] {sex=Male,
#        capital-gain=None,
#        capital-loss=None,
#        native-country=United-States}      => {race=White}                        0.4579256  0.9006927 1.0533890
# [123] {workclass=Private,
#        sex=Male,
#        capital-gain=None,
#        capital-loss=None,
#        native-country=United-States}      => {race=White}                        0.3121084  0.8998288 1.0523787
# [124] {marital-status=Married-civ-spouse} => {race=White}                        0.4105892  0.8961080 1.0480270
# [125] {workclass=Private,
#        income=small}                      => {capital-gain=None}                 0.3488186  0.9607511 1.0472696
# [126] {marital-status=Married-civ-spouse,
#        capital-loss=None}                 => {race=White}                        0.3844232  0.8954597 1.0472689
# [127] {workclass=Private,
#        native-country=United-States,
#        income=small}                      => {capital-gain=None}                 0.3066214  0.9603694 1.0468534
# [128] {hours-per-week=Full-time,
#        income=small}                      => {capital-gain=None}                 0.3010114  0.9602247 1.0466957
# [129] {workclass=Private,
#        capital-loss=None,
#        income=small}                      => {capital-gain=None}                 0.3384178  0.9595936 1.0460078
# [130] {marital-status=Married-civ-spouse,
#        capital-gain=None}                 => {race=White}                        0.3606322  0.8942933 1.0459047
# [131] {marital-status=Married-civ-spouse,
#        capital-gain=None,
#        capital-loss=None}                 => {race=White}                        0.3344662  0.8934099 1.0448716
# [132] {income=small}                      => {capital-gain=None}                 0.4849310  0.9581311 1.0444135
# [133] {marital-status=Never-married}      => {capital-gain=None}                 0.3161214  0.9579947 1.0442649
# [134] {native-country=United-States,
#        income=small}                      => {capital-gain=None}                 0.4313501  0.9576799 1.0439217
# [135] {capital-loss=None,
#        income=small}                      => {capital-gain=None}                 0.4696573  0.9568282 1.0429934
# [136] {marital-status=Never-married,
#        capital-loss=None}                 => {capital-gain=None}                 0.3061300  0.9566831 1.0428352
# [137] {race=White,
#        native-country=United-States,
#        income=small}                      => {capital-gain=None}                 0.3705213  0.9566527 1.0428021
# [138] {race=White,
#        income=small}                      => {capital-gain=None}                 0.4054093  0.9566163 1.0427623
# [139] {capital-loss=None,
#        native-country=United-States,
#        income=small}                      => {capital-gain=None}                 0.4175505  0.9563423 1.0424637
# [140] {race=White,
#        capital-loss=None,
#        income=small}                      => {capital-gain=None}                 0.3923058  0.9552321 1.0412535
# [141] {race=White,
#        capital-loss=None,
#        native-country=United-States,
#        income=small}                      => {capital-gain=None}                 0.3581549  0.9552231 1.0412437
# [142] {relationship=Husband,
#        race=White}                        => {native-country=United-States}      0.3384587  0.9256916 1.0314982
# [143] {relationship=Husband,
#        race=White,
# ...
# [454] {marital-status=Married-civ-spouse,
#        capital-gain=None}                 => {capital-loss=None}                 0.3743704  0.9283611 0.9738619
# [455] {marital-status=Married-civ-spouse,
#        sex=Male,
#        capital-gain=None}                 => {capital-loss=None}                 0.3328283  0.9279068 0.9733854
# [456] {marital-status=Married-civ-spouse,
#        race=White,
#        capital-gain=None}                 => {capital-loss=None}                 0.3344662  0.9274441 0.9729000
# [457] {relationship=Husband,
#        capital-gain=None}                 => {capital-loss=None}                 0.3294501  0.9274352 0.9728906
# [458] {relationship=Husband,
#        sex=Male,
#        capital-gain=None}                 => {capital-loss=None}                 0.3294296  0.9274310 0.9728862
# [459] {marital-status=Married-civ-spouse,
#        relationship=Husband,
#        capital-gain=None}                 => {capital-loss=None}                 0.3292248  0.9273891 0.9728423
# [460] {marital-status=Married-civ-spouse,
#        relationship=Husband,
#        sex=Male,
#        capital-gain=None}                 => {capital-loss=None}                 0.3292044  0.9273849 0.9728380
# [461] {marital-status=Married-civ-spouse,
#        race=White,
#        sex=Male,
#        capital-gain=None}                 => {capital-loss=None}                 0.3002948  0.9272348 0.9726805
# [462] {marital-status=Married-civ-spouse,
#        capital-gain=None,
#        native-country=United-States}      => {capital-loss=None}                 0.3335244  0.9270958 0.9725346
# [463] {workclass=Private,
#        hours-per-week=Full-time}          => {native-country=United-States}      0.3686991  0.8726920 0.9724408
# [464] {workclass=Private,
#        capital-loss=None,
#        hours-per-week=Full-time}          => {native-country=United-States}      0.3543057  0.8717445 0.9713849
# [465] {marital-status=Married-civ-spouse,
#        race=White,
#        capital-gain=None,
#        native-country=United-States}      => {capital-loss=None}                 0.3074403  0.9254854 0.9708453
# [466] {workclass=Private,
#        capital-gain=None,
#        hours-per-week=Full-time}          => {native-country=United-States}      0.3440686  0.8705901 0.9700986
# [467] {workclass=Private,
#        hours-per-week=Full-time}          => {race=White}                        0.3501495  0.8287860 0.9692919
# [468] {workclass=Private,
#        capital-gain=None,
#        capital-loss=None,
#        hours-per-week=Full-time}          => {native-country=United-States}      0.3296753  0.8694854 0.9688676
# [469] {workclass=Private,
#        capital-loss=None,
#        hours-per-week=Full-time}          => {race=White}                        0.3365751  0.8281195 0.9685123
# [470] {workclass=Private,
#        capital-gain=None,
#        hours-per-week=Full-time}          => {race=White}                        0.3265223  0.8261928 0.9662590
# [471] {workclass=Private,
#        capital-gain=None,
#        capital-loss=None,
#        hours-per-week=Full-time}          => {race=White}                        0.3129479  0.8253685 0.9652950
# [472] {hours-per-week=Full-time}          => {race=White}                        0.4824741  0.8246142 0.9644128
# [473] {capital-loss=None,
#        hours-per-week=Full-time}          => {race=White}                        0.4618566  0.8237657 0.9634204
# [474] {capital-gain=None,
#        hours-per-week=Full-time}          => {race=White}                        0.4468081  0.8219586 0.9613069
# [475] {capital-gain=None,
#        capital-loss=None,
#        hours-per-week=Full-time}          => {race=White}                        0.4261906  0.8209173 0.9600891
# [476] {marital-status=Married-civ-spouse,
#        sex=Male}                          => {capital-gain=None}                 0.3586872  0.8803960 0.9596782
# [477] {marital-status=Married-civ-spouse} => {capital-gain=None}                 0.4032595  0.8801108 0.9593673
# [478] {relationship=Husband}              => {capital-gain=None}                 0.3552271  0.8799959 0.9592421
# [479] {relationship=Husband,
#        sex=Male}                          => {capital-gain=None}                 0.3552066  0.8799899 0.9592355
# [480] {marital-status=Married-civ-spouse,
#        relationship=Husband}              => {capital-gain=None}                 0.3550018  0.8799736 0.9592178
# [481] {marital-status=Married-civ-spouse,
#        relationship=Husband,
#        sex=Male}                          => {capital-gain=None}                 0.3549814  0.8799675 0.9592111
# [482] {marital-status=Married-civ-spouse,
#        sex=Male,
#        native-country=United-States}      => {capital-gain=None}                 0.3213423  0.8789270 0.9580770
# [483] {marital-status=Married-civ-spouse,
#        race=White,
#        sex=Male}                          => {capital-gain=None}                 0.3238606  0.8789243 0.9580739
# [484] {relationship=Husband,
#        native-country=United-States}      => {capital-gain=None}                 0.3190287  0.8787007 0.9578303
# [485] {relationship=Husband,
#        sex=Male,
#        native-country=United-States}      => {capital-gain=None}                 0.3190082  0.8786939 0.9578228
# [486] {marital-status=Married-civ-spouse,
#        relationship=Husband,
#        native-country=United-States}      => {capital-gain=None}                 0.3188035  0.8786750 0.9578022
# [487] {marital-status=Married-civ-spouse,
#        relationship=Husband,
#        sex=Male,
#        native-country=United-States}      => {capital-gain=None}                 0.3187830  0.8786682 0.9577948
# [488] {relationship=Husband,
#        race=White}                        => {capital-gain=None}                 0.3212604  0.8786538 0.9577791
# [489] {relationship=Husband,
#        race=White,
#        sex=Male}                          => {capital-gain=None}                 0.3212399  0.8786470 0.9577717
# [490] {marital-status=Married-civ-spouse,
#        relationship=Husband,
#        race=White}                        => {capital-gain=None}                 0.3210761  0.8786419 0.9577661
# [491] {marital-status=Married-civ-spouse,
#        relationship=Husband,
#        race=White,
#        sex=Male}                          => {capital-gain=None}                 0.3210556  0.8786351 0.9577587
# [492] {marital-status=Married-civ-spouse,
#        native-country=United-States}      => {capital-gain=None}                 0.3597519  0.8784182 0.9575223
# [493] {marital-status=Married-civ-spouse,
#        race=White}                        => {capital-gain=None}                 0.3606322  0.8783285 0.9574245
# [494] {marital-status=Married-civ-spouse,
#        race=White,
#        native-country=United-States}      => {capital-gain=None}                 0.3321936  0.8769322 0.9559025
# [495] {marital-status=Married-civ-spouse,
#        sex=Male,
#        capital-loss=None}                 => {capital-gain=None}                 0.3328283  0.8722902 0.9508424
# [496] {marital-status=Married-civ-spouse,
#        capital-loss=None}                 => {capital-gain=None}                 0.3743704  0.8720431 0.9505731
# [497] {relationship=Husband,
#        capital-loss=None}                 => {capital-gain=None}                 0.3294501  0.8718102 0.9503192
# [498] {relationship=Husband,
#        sex=Male,
#        capital-loss=None}                 => {capital-gain=None}                 0.3294296  0.8718032 0.9503116
# [499] {marital-status=Married-civ-spouse,
#        relationship=Husband,
#        capital-loss=None}                 => {capital-gain=None}                 0.3292248  0.8717810 0.9502874
# [500] {marital-status=Married-civ-spouse,
#        relationship=Husband,
#        sex=Male,
#        capital-loss=None}                 => {capital-gain=None}                 0.3292044  0.8717740 0.9502798
# [501] {marital-status=Married-civ-spouse,
#        race=White,
#        sex=Male,
#        capital-loss=None}                 => {capital-gain=None}                 0.3002948  0.8706518 0.9490565
# [502] {marital-status=Married-civ-spouse,
#        capital-loss=None,
#        native-country=United-States}      => {capital-gain=None}                 0.3335244  0.8700993 0.9484543
# [503] {marital-status=Married-civ-spouse,
#        race=White,
#        capital-loss=None}                 => {capital-gain=None}                 0.3344662  0.8700469 0.9483971
# [504] {marital-status=Married-civ-spouse,
#        race=White,
#        capital-loss=None,
#        native-country=United-States}      => {capital-gain=None}                 0.3074403  0.8683282 0.9465237

# %%
subset.matrix <- is.subset(rules.sorted,rules.sorted)
redundant <- apply(subset.matrix, 2, any)
rules.pruned <- rules.sorted[!redundant]
